# %%
from model.Portfolio import Portfolio
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.rcParams["figure.figsize"] = 10, 15

# %%
p = Portfolio()

names = ["5GZ","O39", "CJLU", "Z74", "A17U"]
p = Portfolio()

# Add all assets
for name in names:
    p.addAsset(f"data/{name}.csv", name)

allocation = [0.025, 0.4, 0.1375, 0.1750, 0.1625]


results, plot = p.backtest(allocation)

# %%
message = f"""
Backtested from {results['dateStart'].date()} to {results['dateEnd'].date()} for {results['days']} days
If you've invested ${results['valueStart']}, it will grow/shrink to be ${results['valueEnd']}
The average annual returns is {results['averageReturns']*100:.4f}%, the highest at {results['bestYearReturns']*100:.4f}% and lowest at {results['worstYearReturns']*100:.4f}%
Through the years, there are {results['positiveYears']} years with positive returns and {results['negativeYears']} years with negative returns.
You will experience a drawdown of ${results['moneydown']:.2f} ({results["drawdown"]:.2f}%) lasting {results["drawdownPeriod"]} days.
If you had invested at it's worst, you would've experienced a drawdown of ${results['maxMoneydown']:.2f} ({results["maxDrawdown"]:.2f}%) lasting {results["maxDrawdownPeriod"]} days.
Comparing with a risk-free asset of {p.rf}%, this portfolio has a sharpe ratio of {results["sharpe"]:.4f}
"""

print(message)
# Out:
# Backtested from 2017-07-19 to 2019-06-13 for 694 days
# If you've invested $100000.0, it will grow/shrink to be $144652.52491500002
# The average annual returns is 14.0100%, the highest at 34.8476% and lowest at 1.5847%
# Through the years, there are 3 years with positive returns and 0 years with negative returns.
# You will experience a drawdown of $1836.45 (1.25%) lasting 27 days.
# If you had invested at it's worst, you would've experienced a drawdown of $15645.38 (13.07%) lasting 193 days.
# Comparing with a risk-free asset of 0%, this portfolio has a sharpe ratio of 0.9450

# %%
plot()
# Out:
# <img src="data:image/png;base64,..." width="719.9999843944206">
# [[<Figure size 720x1080 with 9 Axes>]]

# %%
## Issues

Portfolio does not seem to perform rebalancing correctly
Optimiser is returning NaN for most profiles
How to deal with data without time
