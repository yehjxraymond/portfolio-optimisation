# %%
import importlib
import model.Portfolio as Portfolio
from model.Optimizer import Optimizer
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams["figure.figsize"] = 10, 15

# %%
names = ["A35", "ES3"]
p = Portfolio.Portfolio()

# Add all assets
for name in names:
    p.addAsset(f"data/{name}.csv", name)

# %%
allocation = [0.5, 0.5]
results, plot = p.backtest(allocation)

# %%
results
# Out:
# {'dateStart': Timestamp('2008-01-10 00:00:00'),
#  'dateEnd': Timestamp('2019-06-13 00:00:00'),
#  'days': 4172,
#  'valueStart': 100000.0,
#  'valueEnd': 126625.432154,
#  'sharpe': 0.22344341949644145,
#  'drawdown': 1.5294445029499697,
#  'drawdownPeriod': 27,
#  'moneydown': 1966.7459999999846,
#  'maxDrawdown': 32.121345100683754,
#  'maxDrawdownPeriod': 623,
#  'maxMoneydown': 32827.270564999984,
#  'averageReturns': 0.027248447860942483,
#  'standardDeviation': 0.12194786457506948,
#  'positiveYears': 7,
#  'negativeYears': 5,
#  'noChangeYears': 0,
#  'bestYearReturns': 0.2965290316623319,
#  'worstYearReturns': -0.23412822866999994}

# %%
plot()
# Out:
# <img src="data:image/png;base64,..." width="720">
# [[<Figure size 720x1080 with 5 Axes>]]

# %%
o = Optimizer(p)
optimisedWeight, tests = o.kfoldTs(10)

# %%
optimisedWeight
# Out:
# [0.7128207359034452, 0.28717926409655486]

# %%
optimiesdResults, optimisedPlot = p.backtest(optimisedWeight)

# %%
optimiesdResults
# Out:
# {'dateStart': Timestamp('2008-01-10 00:00:00'),
#  'dateEnd': Timestamp('2019-06-13 00:00:00'),
#  'days': 4172,
#  'valueStart': 100000.0,
#  'valueEnd': 128748.368862,
#  'sharpe': 0.33652362842908917,
#  'drawdown': 0.338363091230362,
#  'drawdownPeriod': 30,
#  'moneydown': 437.11599999999453,
#  'maxDrawdown': 20.238925697208145,
#  'maxDrawdownPeriod': 751,
#  'maxMoneydown': 20494.392703999998,
#  'averageReturns': 0.023736848235636033,
#  'standardDeviation': 0.07053545793037162,
#  'positiveYears': 7,
#  'negativeYears': 5,
#  'noChangeYears': 0,
#  'bestYearReturns': 0.171963308242578,
#  'worstYearReturns': -0.12951173986000009}

# %%
optimisedPlot()
# Out:
# <img src="data:image/png;base64,..." width="720">
# [[<Figure size 720x1080 with 5 Axes>]]
